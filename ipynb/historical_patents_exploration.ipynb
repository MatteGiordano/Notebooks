# %%
import pandas as pd
import numpy as np

# %%
hist_masterfile = pd.read_csv('../csv/historical_masterfile.csv')
annual = pd.read_csv('../csv/annual_historical.csv')
# Out:
# C:\Users\matte\AppData\Local\Temp\ipykernel_12256\3588589402.py:1: DtypeWarning: Columns (1,2,4,8,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   hist_masterfile = pd.read_csv('patents us csv/historical_masterfile.csv')

# %%
hist_masterfile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11191813 entries, 0 to 11191812
# Data columns (total 14 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   appl_id     float64
#  1   pubno       object
#  2   patent      object
#  3   nber        int64
#  4   uspc        object
#  5   uspc_sub    object
#  6   appl_dt     object
#  7   prior_dt    object
#  8   pub_dt      object
#  9   disp_dt     object
#  10  disp_ty     object
#  11  exp_dt      object
#  12  exp_dt_max  object
#  13  pta         float64
# dtypes: float64(2), int64(1), object(11)
# memory usage: 1.2+ GB

# %%
annual
# Out:
#      year  total_app  nber11_inforce  nber12_inforce  nber13_inforce  \
# 0    1840        735             114              64              23
# 1    1841        847             129              70              26
# 2    1842        761             144              79              35
# 3    1843        819             156              84              36
# 4    1844       1045             167              89              36
# ..    ...        ...             ...             ...             ...
# 170  2010     339106            4955           22834            7256
# 171  2011     357132            4847           23130            7855
# 172  2012     381508            4877           23849            8466
# 173  2013     402538            4992           24542            9229
# 174  2014     412861            5090           25130            9722
#
#      nber14_inforce  nber15_inforce  nber19_inforce  nber21_inforce  \
# 0                 6               3             217               2
# ...

# %%
hist_masterfile
# Out:
#              appl_id            pubno    patent  nber   uspc uspc_sub  \
# 0                NaN              NaN   0901622    65   30.0      452
# 1          8186218.0              NaN   5448746    22  712.0      210
# 2          8536833.0              NaN   5648952    24  369.0      116
# 3          7499443.0              NaN   5130085    52  420.0       40
# 4                NaN              NaN   2442492    51  241.0      223
# ...              ...              ...       ...   ...    ...      ...
# 11191808  14363933.0  US20150026843A1  -2541071    33    800      298
# 11191809  14496758.0  US20150026844A1  -1792004    33    800      282
# 11191810  14311684.0  US20150026845A1  -3338074    31    435      414
# 11191811  13943023.0  US20150026846A1   -386885    44    850      001
# 11191812  14490812.0  US20150026847A1  -1093120    44    850      021
#
#             appl_dt   prior_dt     pub_dt    disp_dt disp_ty     exp_dt  \
# ...
