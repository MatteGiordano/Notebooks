# %%
import pandas as pd
import numpy as np

# %%
assignor = pd.read_csv('../csv/assignor.csv')
assignor.info()
# Out:
# C:\Users\matte\AppData\Local\Temp\ipykernel_2684\1635870427.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   assignor = pd.read_csv('../csv/assignor.csv')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22798542 entries, 0 to 22798541
# Data columns (total 4 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   rf_id    int64
#  1   or_name  object
#  2   exec_dt  object
#  3   ack_dt   object
# dtypes: int64(1), object(3)
# memory usage: 695.8+ MB

# %%
assignor.head()
# Out:
#       rf_id                            or_name     exec_dt ack_dt
# 0  12800340                     ATALA, ANTHONY  1994-12-22    NaN
# 1  36250888  NORTHERN ELECTRIC COMPANY LIMITED  1976-03-01    NaN
# 2  36340874               ARMSTRONG, THOMAS R.  1979-02-23    NaN
# 3  36340875               ARMSTRONG, THOMAS R.  1979-02-23    NaN
# 4  36920537                         GOULD INC.  1978-10-31    NaN

# %%
assignee = pd.read_csv('../csv/assignee.csv')

# %%
assignee.columns
# Out:
# Index(['rf_id', 'ee_name', 'ee_address_1', 'ee_address_2', 'ee_city',
#        'ee_state', 'ee_postcode', 'ee_country'],
#       dtype='object')

# %%
merged = pd.merge(assignee, assignor, 'inner', on=['rf_id', 'rf_id'])
merged
# Out:
#               rf_id                                         ee_name  \
# 0          12800340           CHILDREN'S MEDICAL CENTER CORPORATION
# 1          36250888                        NORTHERN TELECOM LIMITED
# 2          36340874                            PARADYNE CORPORATION
# 3          36340875                            PARADYNE CORPORATION
# 4          36920537                                       EHD, INC.
# ...             ...                                             ...
# 23914245  591080686                                 CARTICA AI LTD.
# 23914246  591080686                                 CARTICA AI LTD.
# 23914247  591080689  CHINA ACADEMY OF TELECOMMUNICATIONS TECHNOLOGY
# 23914248  591080689  CHINA ACADEMY OF TELECOMMUNICATIONS TECHNOLOGY
# 23914249  591080689  CHINA ACADEMY OF TELECOMMUNICATIONS TECHNOLOGY
#
#                                  ee_address_1        ee_address_2     ee_city  \
# ...
